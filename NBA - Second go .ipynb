# %%
# https://www.kaggle.com/ash316/simple-nba-eda

import numpy as np
import pandas as pd

import numpy as np # linear algebra
import matplotlib.pyplot as plt
import seaborn as sns
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

from subprocess import check_output
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df = pd.read_csv('Seasons_Stats.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Player', 'Pos', 'Age', 'Tm', 'MP', 'FT', 'TRB',
#        'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df['Year'].max()
# Out:
# 2017.0

# %% [markdown]
# We will start analysing 2017
#
# winner - GSW
# MVP - Russ

# %%
df_2017 = df[df['Year']==2017]

# %%
df_2017.head()
# Out:
#        Unnamed: 0    Year        Player Pos   Age   Tm      MP     FT    TRB  \
# 24096       24096  2017.0  Alex Abrines  SG  23.0  OKC  1055.0   44.0   86.0
# 24097       24097  2017.0    Quincy Acy  PF  26.0  TOT   558.0   45.0  115.0
# 24098       24098  2017.0    Quincy Acy  PF  26.0  DAL    48.0    2.0    8.0
# 24099       24099  2017.0    Quincy Acy  PF  26.0  BRK   510.0   43.0  107.0
# 24100       24100  2017.0  Steven Adams   C  23.0  OKC  2389.0  157.0  615.0
#
#         AST   STL   BLK    TOV     PF    PTS
# 24096  40.0  37.0   8.0   33.0  114.0  406.0
# 24097  18.0  14.0  15.0   21.0   67.0  222.0
# 24098   0.0   0.0   0.0    2.0    9.0   13.0
# 24099  18.0  14.0  15.0   19.0   58.0  209.0
# 24100  86.0  88.0  78.0  146.0  195.0  905.0

# %%
df_2017.set_index('Tm',inplace=True)

# %%
df_2017.sort_index()
# Out:
#      Unnamed: 0    Year            Player Pos   Age      MP     FT    TRB  \
# Tm
# ATL       24393  2017.0        Ryan Kelly  PF  25.0   110.0    5.0   18.0
# ATL       24141  2017.0   DeAndre' Bembry  SF  22.0   371.0    6.0   59.0
# ATL       24605  2017.0       Edy Tavares   C  24.0     4.0    0.0    1.0
# ATL       24179  2017.0     Jose Calderon  PG  35.0   247.0    7.0   32.0
# ATL       24578  2017.0   Thabo Sefolosha  SF  32.0  1596.0   55.0  270.0
# ..          ...     ...               ...  ..   ...     ...    ...    ...
# WAS       24646  2017.0         John Wall  PG  26.0  2836.0  422.0  326.0
# WAS       24434  2017.0       Ian Mahinmi   C  30.0   555.0   43.0  150.0
# WAS       24291  2017.0     Marcin Gortat   C  32.0  2556.0  103.0  849.0
# WAS       24491  2017.0  Andrew Nicholson  PF  27.0   231.0    7.0   34.0
# WAS       24574  2017.0  Tomas Satoransky  SG  25.0   719.0   23.0   83.0
#
#        AST    STL   BLK    TOV     PF     PTS
# Tm
# ...

# %%
df_grouped = df_2017.groupby([ 'Tm' ])

# %%
gsw_2017 = df_grouped.get_group(('GSW'))

# %%
okc_2017 = df_grouped.get_group(('OKC'))

# %%
award_defensive_2017 = df_2017[df_2017['Player']=='Draymond Green']
award_MVP_2017 = df_2017[df_2017['Player']=='Russell Westbrook']
award_most_improved_2017 = df_2017[df_2017['Player']=='Giannis Antetokounmpo']
award_sixth_man = df_2017[df_2017['Player']=='Eric Gordon']

# %%
award_most_improved_2017_RunnerUp = df_2017[df_2017['Player']=='Rudy Gobert']
award_most_improved_2017_RunnerUp1 = df_2017[df_2017['Player']=='Nikola Jokic']

# %%
den_2017 = df_grouped.get_group(('DEN'))
den_2017
# Out:
#      Unnamed: 0    Year            Player Pos   Age      MP     FT    TRB  \
# Tm
# DEN       24119  2017.0    Darrell Arthur  PF  28.0   639.0   19.0  112.0
# DEN       24131  2017.0       Will Barton  SG  26.0  1705.0  143.0  258.0
# DEN       24138  2017.0     Malik Beasley  SG  20.0   165.0    8.0   17.0
# DEN       24192  2017.0   Wilson Chandler  SF  29.0  2197.0  141.0  459.0
# DEN       24253  2017.0    Kenneth Faried  PF  27.0  1296.0  131.0  461.0
# DEN       24268  2017.0  Danilo Gallinari  SF  28.0  2134.0  349.0  326.0
# DEN       24277  2017.0        Alonzo Gee  SF  29.0    89.0    5.0   15.0
# DEN       24311  2017.0       Gary Harris  SG  22.0  1782.0  104.0  178.0
# DEN       24324  2017.0  Juan Hernangomez  PF  21.0   842.0   57.0  187.0
# DEN       24329  2017.0       Roy Hibbert   C  30.0    11.0    0.0    2.0
# DEN       24380  2017.0      Nikola Jokic   C  21.0  2038.0  188.0  718.0
# DEN       24464  2017.0       Mike Miller  SF  36.0   151.0    2.0   39.0
# ...

# %%
awarded_2017 = [award_defensive_2017,award_most_improved_2017,award_MVP_2017,award_sixth_man]
awards_2017 = pd.concat(awarded_2017)
awards_2017
awards_2017['Award'] = ['Defensive Player','Most Improved Payer','MVP','Sixth Man']

# %%
awards_2017
# Out:
#      Unnamed: 0    Year                 Player Pos   Age      MP     FT  \
# Tm
# GSW       24298  2017.0         Draymond Green  PF  26.0  2471.0  151.0
# MIL       24115  2017.0  Giannis Antetokounmpo  SF  22.0  2845.0  471.0
# OKC       24654  2017.0      Russell Westbrook  PG  28.0  2802.0  710.0
# HOU       24290  2017.0            Eric Gordon  SG  28.0  2323.0  147.0
#
#        TRB    AST    STL    BLK    TOV     PF     PTS                Award
# Tm
# GSW  599.0  533.0  154.0  106.0  184.0  217.0   776.0     Defensive Player
# MIL  700.0  434.0  131.0  151.0  234.0  246.0  1832.0  Most Improved Payer
# OKC  864.0  840.0  133.0   31.0  438.0  190.0  2558.0                  MVP
# HOU  201.0  188.0   48.0   40.0  121.0  150.0  1217.0            Sixth Man

# %%
top_scorers_2017 = df_2017.sort_values(by='PTS',ascending=False).head(5)

# %%
top_scorers_2017
# Out:
#      Unnamed: 0    Year              Player Pos   Age      MP     FT     TRB  \
# Tm
# OKC       24654  2017.0   Russell Westbrook  PG  28.0  2802.0  710.0   864.0
# HOU       24306  2017.0        James Harden  PG  27.0  2947.0  746.0   659.0
# BOS       24612  2017.0       Isaiah Thomas  PG  27.0  2569.0  590.0   205.0
# NOP       24218  2017.0       Anthony Davis   C  23.0  2708.0  519.0   886.0
# MIN       24625  2017.0  Karl-Anthony Towns   C  21.0  3030.0  356.0  1007.0
#
#        AST    STL    BLK    TOV     PF     PTS
# Tm
# OKC  840.0  133.0   31.0  438.0  190.0  2558.0
# HOU  906.0  120.0   37.0  464.0  215.0  2356.0
# BOS  449.0   70.0   13.0  210.0  167.0  2199.0
# NOP  157.0   94.0  167.0  181.0  168.0  2099.0
# MIN  220.0   57.0  103.0  212.0  241.0  2061.0

# %%
gsw_2017.sort_values(by='PTS',ascending=False,inplace=True)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
sas_2017
# Out:
#       Tm  Unnamed: 0    Year                Player Pos   Age      MP     FT  \
# 11   SAS       24414  2017.0         Kawhi Leonard  SF  25.0  2474.0  469.0
# 40   SAS       24104  2017.0     LaMarcus Aldridge  PF  31.0  2335.0  220.0
# 120  SAS       24274  2017.0             Pau Gasol   C  36.0  1627.0  130.0
# 131  SAS       24465  2017.0           Patty Mills  PG  28.0  1754.0   66.0
# 163  SAS       24518  2017.0           Tony Parker  PG  34.0  1587.0   85.0
# 190  SAS       24412  2017.0             David Lee  PF  33.0  1477.0   80.0
# 216  SAS       24284  2017.0         Manu Ginobili  SG  39.0  1291.0   86.0
# 224  SAS       24297  2017.0           Danny Green  SG  29.0  1807.0   27.0
# 230  SAS       24586  2017.0      Jonathon Simmons  SG  27.0  1392.0   99.0
# 286  SAS       24221  2017.0        Dewayne Dedmon   C  27.0  1330.0   65.0
# 322  SAS       24145  2017.0         Davis Bertans  PF  24.0   808.0   28.0
# ...

# %%
sns.barplot(y='PTS/Game',x='Player',data=gsw_2017.head(6))

# %%
top_blk_2017 = df_2017.sort_values(by='BLK',ascending=False).head(5)

# %%
top_blk_2017
# Out:
#      Unnamed: 0    Year                 Player Pos   Age      MP     FT  \
# Tm
# UTA       24285  2017.0            Rudy Gobert   C  24.0  2744.0  311.0
# IND       24630  2017.0           Myles Turner   C  20.0  2541.0  245.0
# NOP       24218  2017.0          Anthony Davis   C  23.0  2708.0  519.0
# MIA       24657  2017.0       Hassan Whiteside   C  27.0  2513.0  225.0
# MIL       24115  2017.0  Giannis Antetokounmpo  SF  22.0  2845.0  471.0
#
#         TRB    AST    STL    BLK    TOV     PF     PTS
# Tm
# UTA  1035.0   97.0   49.0  214.0  148.0  246.0  1137.0
# IND   587.0  106.0   74.0  173.0  105.0  262.0  1173.0
# NOP   886.0  157.0   94.0  167.0  181.0  168.0  2099.0
# MIA  1088.0   57.0   56.0  161.0  154.0  226.0  1309.0
# MIL   700.0  434.0  131.0  151.0  234.0  246.0  1832.0

# %%
top_stl_2017 = df_2017.sort_values(by='STL',ascending=False).head(5)

# %%
top_stl_2017
# Out:
#      Unnamed: 0    Year          Player Pos   Age      MP     FT    TRB  \
# Tm
# WAS       24646  2017.0       John Wall  PG  26.0  2836.0  422.0  326.0
# GSW       24298  2017.0  Draymond Green  PF  26.0  2471.0  151.0  599.0
# HOU       24118  2017.0    Trevor Ariza  SF  31.0  2773.0   93.0  459.0
# GSW       24216  2017.0   Stephen Curry  PG  28.0  2638.0  325.0  353.0
# CHI       24175  2017.0    Jimmy Butler  SF  27.0  2809.0  585.0  470.0
#
#        AST    STL    BLK    TOV     PF     PTS
# Tm
# WAS  831.0  157.0   49.0  323.0  151.0  1805.0
# GSW  533.0  154.0  106.0  184.0  217.0   776.0
# HOU  175.0  147.0   20.0   74.0  133.0   936.0
# GSW  523.0  143.0   17.0  239.0  183.0  1999.0
# CHI  417.0  143.0   32.0  159.0  112.0  1816.0

# %%
cle_2017 = df_2017[df_2017['Tm']=='CLE']
cle_2017['PTS/Game'] = (cle_2017['PTS']/cle_2017['MP'])*48
cle_2017
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       Tm  Unnamed: 0    Year             Player Pos   Age      MP     FT  \
# 8    CLE       24365  2017.0       LeBron James  SF  32.0  2794.0  358.0
# 15   CLE       24360  2017.0       Kyrie Irving  PG  24.0  2525.0  297.0
# 53   CLE       24428  2017.0         Kevin Love  PF  28.0  1885.0  257.0
# 153  CLE       24267  2017.0      Channing Frye   C  33.0  1398.0   63.0
# 167  CLE       24618  2017.0   Tristan Thompson   C  25.0  2336.0  106.0
# 192  CLE       24584  2017.0      Iman Shumpert  SG  26.0  1937.0   71.0
# 243  CLE       24367  2017.0  Richard Jefferson  SF  36.0  1614.0   80.0
# ...

# %%
sns.catplot(x="Player", y="PTS/Game", kind="bar", data=cle_2017.head(6),height=9,aspect=2)

# %%
sns.catplot(data=gsw_2017.sort_values('PTS/Game',ascending=False).head(6), x='Player', y='PTS', kind="bar",height=9,aspect=2)

# %%
award_defensive_2017['Stl/Min'] = award_defensive_2017['STL']/award_defensive_2017['MP']
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
award_defensive_2017['TRB/Min'] = award_defensive_2017['TRB']/award_defensive_2017['MP']
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
top_TRB_2017 = df_2017.sort_values(by='TRB',ascending=False).head(5)

# %%
top_TRB_2017
# Out:
#      Unnamed: 0    Year              Player Pos   Age      MP     FT     TRB  \
# Tm
# DET       24233  2017.0      Andre Drummond   C  23.0  2409.0  137.0  1116.0
# LAC       24389  2017.0      DeAndre Jordan   C  28.0  2570.0  205.0  1114.0
# MIA       24657  2017.0    Hassan Whiteside   C  27.0  2513.0  225.0  1088.0
# UTA       24285  2017.0         Rudy Gobert   C  24.0  2744.0  311.0  1035.0
# MIN       24625  2017.0  Karl-Anthony Towns   C  21.0  3030.0  356.0  1007.0
#
#        AST    STL    BLK    TOV     PF     PTS
# Tm
# DET   89.0  124.0   89.0  152.0  237.0  1105.0
# LAC   96.0   52.0  135.0  116.0  212.0  1029.0
# MIA   57.0   56.0  161.0  154.0  226.0  1309.0
# UTA   97.0   49.0  214.0  148.0  246.0  1137.0
# MIN  220.0   57.0  103.0  212.0  241.0  2061.0

# %%
top_TRB_2017['TRB/Min'] = top_TRB_2017['TRB']/top_TRB_2017['MP']

# %%
award_defensive_2017
# Out:
#      Unnamed: 0    Year          Player Pos   Age      MP     FT    TRB  \
# Tm
# GSW       24298  2017.0  Draymond Green  PF  26.0  2471.0  151.0  599.0
#
#        AST    STL    BLK    TOV     PF    PTS   Stl/Min   TRB/Min
# Tm
# GSW  533.0  154.0  106.0  184.0  217.0  776.0  0.062323  0.242412

# %%
top_STL_2017 = df_2017.sort_values(by='STL',ascending=False).head(5)
top_STL_2017['STL/Min'] = top_STL_2017['STL']/top_STL_2017['MP']
top_STL_2017
# Out:
#      Unnamed: 0    Year          Player Pos   Age      MP     FT    TRB  \
# Tm
# WAS       24646  2017.0       John Wall  PG  26.0  2836.0  422.0  326.0
# GSW       24298  2017.0  Draymond Green  PF  26.0  2471.0  151.0  599.0
# HOU       24118  2017.0    Trevor Ariza  SF  31.0  2773.0   93.0  459.0
# GSW       24216  2017.0   Stephen Curry  PG  28.0  2638.0  325.0  353.0
# CHI       24175  2017.0    Jimmy Butler  SF  27.0  2809.0  585.0  470.0
#
#        AST    STL    BLK    TOV     PF     PTS   STL/Min
# Tm
# WAS  831.0  157.0   49.0  323.0  151.0  1805.0  0.055360
# GSW  533.0  154.0  106.0  184.0  217.0   776.0  0.062323
# HOU  175.0  147.0   20.0   74.0  133.0   936.0  0.053011
# GSW  523.0  143.0   17.0  239.0  183.0  1999.0  0.054208
# CHI  417.0  143.0   32.0  159.0  112.0  1816.0  0.050908

# %%
top_BLK_2017 = df_2017.sort_values(by='BLK',ascending=False).head(5)
top_BLK_2017['BLK/Min'] = top_BLK_2017['BLK']/top_BLK_2017['MP']
top_BLK_2017
# Out:
#      Unnamed: 0    Year                 Player Pos   Age      MP     FT  \
# Tm
# UTA       24285  2017.0            Rudy Gobert   C  24.0  2744.0  311.0
# IND       24630  2017.0           Myles Turner   C  20.0  2541.0  245.0
# NOP       24218  2017.0          Anthony Davis   C  23.0  2708.0  519.0
# MIA       24657  2017.0       Hassan Whiteside   C  27.0  2513.0  225.0
# MIL       24115  2017.0  Giannis Antetokounmpo  SF  22.0  2845.0  471.0
#
#         TRB    AST    STL    BLK    TOV     PF     PTS   BLK/Min
# Tm
# UTA  1035.0   97.0   49.0  214.0  148.0  246.0  1137.0  0.077988
# IND   587.0  106.0   74.0  173.0  105.0  262.0  1173.0  0.068083
# NOP   886.0  157.0   94.0  167.0  181.0  168.0  2099.0  0.061669
# MIA  1088.0   57.0   56.0  161.0  154.0  226.0  1309.0  0.064067
# MIL   700.0  434.0  131.0  151.0  234.0  246.0  1832.0  0.053076

# %%
award_MVP_2017
# Out:
#      Unnamed: 0    Year             Player Pos   Age      MP     FT    TRB  \
# Tm
# OKC       24654  2017.0  Russell Westbrook  PG  28.0  2802.0  710.0  864.0
#
#        AST    STL   BLK    TOV     PF     PTS
# Tm
# OKC  840.0  133.0  31.0  438.0  190.0  2558.0

# %%
top_FT_2017 = df_2017.sort_values(by='FT',ascending=False).head(5)
top_FT_2017['(FT/Game)'] = (top_FT_2017['FT']/top_FT_2017['MP'])*48
top_FT_2017
# Out:
#      Unnamed: 0    Year             Player Pos   Age      MP     FT    TRB  \
# Tm
# HOU       24306  2017.0       James Harden  PG  27.0  2947.0  746.0  659.0
# OKC       24654  2017.0  Russell Westbrook  PG  28.0  2802.0  710.0  864.0
# BOS       24612  2017.0      Isaiah Thomas  PG  27.0  2569.0  590.0  205.0
# CHI       24175  2017.0       Jimmy Butler  SF  27.0  2809.0  585.0  470.0
# TOR       24226  2017.0      DeMar DeRozan  SG  27.0  2620.0  545.0  386.0
#
#        AST    STL   BLK    TOV     PF     PTS  (FT/Game)
# Tm
# HOU  906.0  120.0  37.0  464.0  215.0  2356.0  12.150662
# OKC  840.0  133.0  31.0  438.0  190.0  2558.0  12.162741
# BOS  449.0   70.0  13.0  210.0  167.0  2199.0  11.023745
# CHI  417.0  143.0  32.0  159.0  112.0  1816.0   9.996440
# TOR  290.0   78.0  13.0  180.0  134.0  2020.0   9.984733

# %%
top_AST_2017 = df_2017.sort_values(by='AST',ascending=False).head(5)
top_AST_2017['AST/Game'] = (top_AST_2017['AST']/top_AST_2017['MP'])*48
top_AST_2017
# Out:
#      Unnamed: 0    Year             Player Pos   Age      MP     FT    TRB  \
# Tm
# HOU       24306  2017.0       James Harden  PG  27.0  2947.0  746.0  659.0
# OKC       24654  2017.0  Russell Westbrook  PG  28.0  2802.0  710.0  864.0
# WAS       24646  2017.0          John Wall  PG  26.0  2836.0  422.0  326.0
# MIN       24567  2017.0        Ricky Rubio  PG  26.0  2469.0  254.0  305.0
# CLE       24365  2017.0       LeBron James  SF  32.0  2794.0  358.0  640.0
#
#        AST    STL   BLK    TOV     PF     PTS   AST/Game
# Tm
# HOU  906.0  120.0  37.0  464.0  215.0  2356.0  14.756702
# OKC  840.0  133.0  31.0  438.0  190.0  2558.0  14.389722
# WAS  831.0  157.0  49.0  323.0  151.0  1805.0  14.064880
# MIN  682.0  128.0  10.0  195.0  202.0   836.0  13.258809
# CLE  646.0   92.0  44.0  303.0  134.0  1954.0  11.098067

# %%
top_STL_2017 = df_2017.sort_values(by='STL',ascending=False).head(5)
top_STL_2017['STL/Game'] = (top_STL_2017['STL']/top_STL_2017['MP'])*48
top_STL_2017
# Out:
#      Unnamed: 0    Year          Player Pos   Age      MP     FT    TRB  \
# Tm
# WAS       24646  2017.0       John Wall  PG  26.0  2836.0  422.0  326.0
# GSW       24298  2017.0  Draymond Green  PF  26.0  2471.0  151.0  599.0
# HOU       24118  2017.0    Trevor Ariza  SF  31.0  2773.0   93.0  459.0
# GSW       24216  2017.0   Stephen Curry  PG  28.0  2638.0  325.0  353.0
# CHI       24175  2017.0    Jimmy Butler  SF  27.0  2809.0  585.0  470.0
#
#        AST    STL    BLK    TOV     PF     PTS  STL/Game
# Tm
# WAS  831.0  157.0   49.0  323.0  151.0  1805.0  2.657264
# GSW  533.0  154.0  106.0  184.0  217.0   776.0  2.991501
# HOU  175.0  147.0   20.0   74.0  133.0   936.0  2.544537
# GSW  523.0  143.0   17.0  239.0  183.0  1999.0  2.601971
# CHI  417.0  143.0   32.0  159.0  112.0  1816.0  2.443574

# %%
top_TOV_2017 = df_2017.sort_values(by='TOV',ascending=False).head(5)
top_TOV_2017['TOV/Game'] = (top_TOV_2017['TOV']/top_TOV_2017['MP'])*48
top_TOV_2017
# Out:
#      Unnamed: 0    Year             Player Pos   Age      MP     FT    TRB  \
# Tm
# HOU       24306  2017.0       James Harden  PG  27.0  2947.0  746.0  659.0
# OKC       24654  2017.0  Russell Westbrook  PG  28.0  2802.0  710.0  864.0
# WAS       24646  2017.0          John Wall  PG  26.0  2836.0  422.0  326.0
# CLE       24365  2017.0       LeBron James  SF  32.0  2794.0  358.0  640.0
# TOT       24206  2017.0   DeMarcus Cousins   C  26.0  2465.0  517.0  797.0
#
#        AST    STL   BLK    TOV     PF     PTS  TOV/Game
# Tm
# HOU  906.0  120.0  37.0  464.0  215.0  2356.0  7.557516
# OKC  840.0  133.0  31.0  438.0  190.0  2558.0  7.503212
# WAS  831.0  157.0  49.0  323.0  151.0  1805.0  5.466855
# CLE  646.0   92.0  44.0  303.0  134.0  1954.0  5.205440
# TOT  332.0  100.0  92.0  269.0  278.0  1942.0  5.238134

# %%
top_PTS_2017 = df_2017.sort_values(by='PTS',ascending=False).head(5)
top_PTS_2017['PTS/Game'] = (top_PTS_2017['PTS']/top_PTS_2017['MP'])*48
top_PTS_2017
# Out:
#      Unnamed: 0    Year              Player Pos   Age      MP     FT     TRB  \
# Tm
# OKC       24654  2017.0   Russell Westbrook  PG  28.0  2802.0  710.0   864.0
# HOU       24306  2017.0        James Harden  PG  27.0  2947.0  746.0   659.0
# BOS       24612  2017.0       Isaiah Thomas  PG  27.0  2569.0  590.0   205.0
# NOP       24218  2017.0       Anthony Davis   C  23.0  2708.0  519.0   886.0
# MIN       24625  2017.0  Karl-Anthony Towns   C  21.0  3030.0  356.0  1007.0
#
#        AST    STL    BLK    TOV     PF     PTS   PTS/Game
# Tm
# OKC  840.0  133.0   31.0  438.0  190.0  2558.0  43.820128
# HOU  906.0  120.0   37.0  464.0  215.0  2356.0  38.373940
# BOS  449.0   70.0   13.0  210.0  167.0  2199.0  41.086804
# NOP  157.0   94.0  167.0  181.0  168.0  2099.0  37.205318
# MIN  220.0   57.0  103.0  212.0  241.0  2061.0  32.649505

# %%
award_most_improved_2017_RunnerUp 
award_most_improved_2017_RunnerUp1
award_most_improved_2017
# Out:
#      Unnamed: 0    Year                 Player Pos   Age      MP     FT  \
# Tm
# MIL       24115  2017.0  Giannis Antetokounmpo  SF  22.0  2845.0  471.0
#
#        TRB    AST    STL    BLK    TOV     PF     PTS
# Tm
# MIL  700.0  434.0  131.0  151.0  234.0  246.0  1832.0

# %%
award_most_improved = [award_most_improved_2017,award_most_improved_2017_RunnerUp,award_most_improved_2017_RunnerUp1]

# %%
award_most_improved = pd.concat(award_most_improved)

# %%
type(award_most_improved)
# Out:
# pandas.core.frame.DataFrame

# %%
award_most_improved_2017_RunnerUp1
# Out:
#      Unnamed: 0    Year        Player Pos   Age      MP     FT    TRB    AST  \
# Tm
# DEN       24380  2017.0  Nikola Jokic   C  21.0  2038.0  188.0  718.0  359.0
#
#       STL   BLK    TOV     PF     PTS
# Tm
# DEN  61.0  56.0  171.0  214.0  1221.0

# %%
award_most_improved_2017_RunnerUp
# Out:
#      Unnamed: 0    Year       Player Pos   Age      MP     FT     TRB   AST  \
# Tm
# UTA       24285  2017.0  Rudy Gobert   C  24.0  2744.0  311.0  1035.0  97.0
#
#       STL    BLK    TOV     PF     PTS
# Tm
# UTA  49.0  214.0  148.0  246.0  1137.0

# %%
df_2016 = df[df['Year']==2016]

# %%
df_2016_MostImproved = df_2016[(df_2016['Player']=='Giannis Antetokounmpo')|(df_2016['Player']=='Rudy Gobert')|(df_2016['Player']=='Nikola Jokic')]

# %%
most_improved_2016_2017 = pd.concat([df_2016_MostImproved, award_most_improved])

# %%
most_improved_2016_2017.sort_values('Player')
# Out:
#        Unnamed: 0    Year                 Player Pos   Age   Tm      MP  \
# 23537       23537  2016.0  Giannis Antetokounmpo  PG  21.0  MIL  2823.0
# MIL         24115  2017.0  Giannis Antetokounmpo  SF  22.0  NaN  2845.0
# 23804       23804  2016.0           Nikola Jokic   C  20.0  DEN  1733.0
# DEN         24380  2017.0           Nikola Jokic   C  21.0  NaN  2038.0
# 23695       23695  2016.0            Rudy Gobert   C  23.0  UTA  1932.0
# UTA         24285  2017.0            Rudy Gobert   C  24.0  NaN  2744.0
#
#           FT     TRB    AST    STL    BLK    TOV     PF     PTS
# 23537  296.0   612.0  345.0   94.0  113.0  208.0  258.0  1350.0
# MIL    471.0   700.0  434.0  131.0  151.0  234.0  246.0  1832.0
# 23804  154.0   560.0  189.0   79.0   50.0  104.0  208.0   796.0
# DEN    188.0   718.0  359.0   61.0   56.0  171.0  214.0  1221.0
# 23695  161.0   668.0   91.0   45.0  135.0  114.0  163.0   557.0
# UTA    311.0  1035.0   97.0   49.0  214.0  148.0  246.0  1137.0

# %%
df_2016=df[df['Year']==2016
# Out:
#   File "<ipython-input-50-b84b010e72c4>", line 1
#     df_2016=df[df['Year']==2016
#                                ^
# SyntaxError: unexpected EOF while parsing

# %%
df_2016 = df[df['Year']==2016]

# %%
award_MVP_2016 = df_2016[df_2016['Player']=='Stephen Curry']

# %%
award_defensive_2016 = df_2016[df_2016['Player']=='Kawhi Leonard']

# %%
award_most_improved_2016 = df_2016[df_2016['Player']=='C.J. McCollum']

# %%
df_2016[df_2016['Tm']=='POR']
# Out:
#        Unnamed: 0    Year            Player Pos   Age   Tm      MP     FT  \
# 23524       23524  2016.0   Cliff Alexander  PF  20.0  POR    36.0    0.0
# 23527       23527  2016.0   Al-Farouq Aminu  SF  25.0  POR  2341.0  115.0
# 23618       23618  2016.0   Pat Connaughton  SG  23.0  POR   143.0    5.0
# 23625       23625  2016.0      Allen Crabbe  SG  23.0  POR  2105.0   98.0
# 23636       23636  2016.0          Ed Davis  PF  26.0  POR  1684.0  114.0
# 23677       23677  2016.0       Tim Frazier  PG  25.0  POR   272.0    8.0
# 23723       23723  2016.0  Maurice Harkless  SF  22.0  POR  1457.0   69.0
# 23737       23737  2016.0  Gerald Henderson  SG  28.0  POR  1431.0  112.0
# 23811       23811  2016.0       Chris Kaman   C  33.0  POR   112.0    3.0
# 23840       23840  2016.0    Meyers Leonard  PF  23.0  POR  1333.0   35.0
# 23842       23842  2016.0    Damian Lillard  PG  25.0  POR  2676.0  414.0
# 23869       23869  2016.0     C.J. McCollum  SG  24.0  POR  2780.0  187.0
# ...

# %%
awarded_2016 = [award_defensive_2016, award_most_improved_2016, award_MVP_2016]
awards_2016 = pd.concat(awarded_2016)
awards_2016
awards_2016['Award'] = ['Defensive Player','Most Improved Payer','MVP']

# %%
awards_2016
# Out:
#        Unnamed: 0    Year         Player Pos   Age   Tm      MP     FT    TRB  \
# 23839       23839  2016.0  Kawhi Leonard  SF  24.0  SAS  2380.0  292.0  493.0
# 23869       23869  2016.0  C.J. McCollum  SG  24.0  POR  2780.0  187.0  259.0
# 23633       23633  2016.0  Stephen Curry  PG  27.0  GSW  2700.0  363.0  430.0
#
#          AST    STL   BLK    TOV     PF     PTS                Award
# 23839  186.0  128.0  71.0  105.0  133.0  1523.0     Defensive Player
# 23869  341.0   97.0  23.0  196.0  187.0  1666.0  Most Improved Payer
# 23633  527.0  169.0  15.0  262.0  161.0  2375.0                  MVP

# %%
top_FT_2016 = df_2016.sort_values(by='FT',ascending=False).head(5)

# %%
top_FT_2016
# Out:
#        Unnamed: 0    Year             Player Pos   Age   Tm      MP     FT  \
# 23722       23722  2016.0       James Harden  SG  26.0  HOU  3125.0  720.0
# 23643       23643  2016.0      DeMar DeRozan  SG  26.0  TOR  2804.0  555.0
# 23623       23623  2016.0   DeMarcus Cousins   C  25.0  SAC  2246.0  476.0
# 24027       24027  2016.0      Isaiah Thomas  PG  26.0  BOS  2644.0  474.0
# 24070       24070  2016.0  Russell Westbrook  PG  27.0  OKC  2750.0  465.0
#
#          TRB    AST    STL   BLK    TOV     PF     PTS
# 23722  501.0  612.0  139.0  51.0  374.0  229.0  2376.0
# 23643  349.0  315.0   81.0  21.0  175.0  167.0  1830.0
# 23623  747.0  214.0  101.0  92.0  249.0  236.0  1748.0
# 24027  243.0  509.0   91.0   9.0  220.0  167.0  1823.0
# 24070  626.0  834.0  163.0  20.0  342.0  200.0  1878.0

# %%
top_TRB_2016 = df_2016.sort_values(by='TRB',ascending=False).head(5)

# %%
top_TRB_2016
# Out:
#        Unnamed: 0    Year              Player Pos   Age   Tm      MP     FT  \
# 23649       23649  2016.0      Andre Drummond   C  22.0  DET  2666.0  208.0
# 23809       23809  2016.0      DeAndre Jordan   C  27.0  LAC  2598.0  266.0
# 24071       24071  2016.0    Hassan Whiteside   C  26.0  MIA  2125.0  214.0
# 24040       24040  2016.0  Karl-Anthony Towns   C  20.0  MIN  2627.0  223.0
# 23763       23763  2016.0       Dwight Howard   C  30.0  HOU  2280.0  232.0
#
#           TRB    AST    STL    BLK    TOV     PF     PTS
# 23649  1198.0   67.0  119.0  112.0  155.0  245.0  1314.0
# 23809  1059.0   90.0   51.0  177.0  107.0  207.0   980.0
# 24071   865.0   30.0   44.0  269.0  137.0  201.0  1040.0
# 24040   858.0  161.0   58.0  138.0  183.0  245.0  1503.0
# 23763   835.0   98.0   69.0  113.0  166.0  219.0   976.0

# %%
top_AST_2016 = df_2016.sort_values(by='AST',ascending=False).head(5)
top_AST_2016
# Out:
#        Unnamed: 0    Year             Player Pos   Age   Tm      MP     FT  \
# 23972       23972  2016.0        Rajon Rondo  PG  29.0  SAC  2537.0   87.0
# 24070       24070  2016.0  Russell Westbrook  PG  27.0  OKC  2750.0  465.0
# 24060       24060  2016.0          John Wall  PG  25.0  WAS  2784.0  272.0
# 23938       23938  2016.0         Chris Paul  PG  30.0  LAC  2420.0  294.0
# 23976       23976  2016.0        Ricky Rubio  PG  25.0  MIN  2323.0  266.0
#
#          TRB    AST    STL   BLK    TOV     PF     PTS
# 23972  435.0  839.0  141.0  10.0  278.0  175.0   859.0
# 24070  626.0  834.0  163.0  20.0  342.0  200.0  1878.0
# 24060  379.0  789.0  145.0  59.0  318.0  159.0  1531.0
# 23938  310.0  738.0  152.0  13.0  194.0  185.0  1446.0
# 23976  326.0  658.0  162.0  10.0  193.0  201.0   766.0

# %%
sns.catplot(x="Player", y="AST", kind="bar", data=top_AST_2016,aspect=1.5)

# %%
top_STL_2016 = df_2016.sort_values(by='STL',ascending=False).head(5)
top_STL_2016
# Out:
#        Unnamed: 0    Year             Player Pos   Age   Tm      MP     FT  \
# 23633       23633  2016.0      Stephen Curry  PG  27.0  GSW  2700.0  363.0
# 24070       24070  2016.0  Russell Westbrook  PG  27.0  OKC  2750.0  465.0
# 23976       23976  2016.0        Ricky Rubio  PG  25.0  MIN  2323.0  266.0
# 23542       23542  2016.0       Trevor Ariza  SF  30.0  HOU  2859.0  126.0
# 23849       23849  2016.0         Kyle Lowry  PG  29.0  TOR  2851.0  398.0
#
#          TRB    AST    STL   BLK    TOV     PF     PTS
# 23633  430.0  527.0  169.0  15.0  262.0  161.0  2375.0
# 24070  626.0  834.0  163.0  20.0  342.0  200.0  1878.0
# 23976  326.0  658.0  162.0  10.0  193.0  201.0   766.0
# 23542  366.0  188.0  160.0  26.0  113.0  177.0  1025.0
# 23849  365.0  494.0  158.0  34.0  225.0  211.0  1634.0

# %%
top_BLK_2016 = df_2016.sort_values(by='BLK',ascending=False).head(5)
top_BLK_2016
# Out:
#        Unnamed: 0    Year            Player Pos   Age   Tm      MP     FT  \
# 24071       24071  2016.0  Hassan Whiteside   C  26.0  MIA  2125.0  214.0
# 23809       23809  2016.0    DeAndre Jordan   C  27.0  LAC  2598.0  266.0
# 23771       23771  2016.0       Serge Ibaka  PF  26.0  OKC  2500.0   91.0
# 23689       23689  2016.0         Pau Gasol   C  35.0  CHI  2291.0  229.0
# 23892       23892  2016.0      Paul Millsap  PF  30.0  ATL  2647.0  309.0
#
#           TRB    AST    STL    BLK    TOV     PF     PTS
# 24071   865.0   30.0   44.0  269.0  137.0  201.0  1040.0
# 23809  1059.0   90.0   51.0  177.0  107.0  207.0   980.0
# 23771   533.0   66.0   38.0  148.0  108.0  211.0   983.0
# 23689   793.0  294.0   42.0  146.0  164.0  148.0  1187.0
# 23892   732.0  265.0  147.0  139.0  191.0  237.0  1385.0

# %%
top_TOV_2016 = df_2016.sort_values(by='TOV',ascending=False).head(5)
top_TOV_2016
# Out:
#        Unnamed: 0    Year             Player Pos   Age   Tm      MP     FT  \
# 23722       23722  2016.0       James Harden  SG  26.0  HOU  3125.0  720.0
# 24070       24070  2016.0  Russell Westbrook  PG  27.0  OKC  2750.0  465.0
# 24060       24060  2016.0          John Wall  PG  25.0  WAS  2784.0  272.0
# 23972       23972  2016.0        Rajon Rondo  PG  29.0  SAC  2537.0   87.0
# 23692       23692  2016.0        Paul George  SF  25.0  IND  2819.0  454.0
#
#          TRB    AST    STL   BLK    TOV     PF     PTS
# 23722  501.0  612.0  139.0  51.0  374.0  229.0  2376.0
# 24070  626.0  834.0  163.0  20.0  342.0  200.0  1878.0
# 24060  379.0  789.0  145.0  59.0  318.0  159.0  1531.0
# 23972  435.0  839.0  141.0  10.0  278.0  175.0   859.0
# 23692  563.0  329.0  152.0  29.0  265.0  230.0  1874.0

# %%
df_2016.sort_values(by='PTS',ascending=False,inplace=True)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2016.set_index('Player',inplace=True)

# %%
df_2016.loc['Stephen Curry'].rank()
# Out:
# Series([], Name: Stephen Curry, dtype: float64)

# %%
df_2016[df_2016['Player']=='LeBron James'].index
# Out:
# Int64Index([3], dtype='int64')

# %%
df_2016.reset_index(inplace=True)

# %%
df_2016.head()
# Out:
#    index          Player  Unnamed: 0    Year Pos   Age   Tm      MP     FT  \
# 0      0    James Harden       23722  2016.0  SG  26.0  HOU  3125.0  720.0
# 1      1   Stephen Curry       23633  2016.0  PG  27.0  GSW  2700.0  363.0
# 2      2    Kevin Durant       23654  2016.0  SF  27.0  OKC  2578.0  447.0
# 3      3    LeBron James       23781  2016.0  SF  31.0  CLE  2709.0  359.0
# 4      4  Damian Lillard       23842  2016.0  PG  25.0  POR  2676.0  414.0
#
#      TRB    AST    STL   BLK    TOV     PF     PTS
# 0  501.0  612.0  139.0  51.0  374.0  229.0  2376.0
# 1  430.0  527.0  169.0  15.0  262.0  161.0  2375.0
# 2  589.0  361.0   69.0  85.0  250.0  137.0  2029.0
# 3  565.0  514.0  104.0  49.0  249.0  143.0  1920.0
# 4  302.0  512.0   65.0  28.0  242.0  165.0  1879.0

# %%
df_2017.sort_values(by='PTS',ascending=False,inplace=True)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2017[df_2017['Player']=='Kevin Durant'].index
# Out:
# Int64Index([24], dtype='int64')

# %%
df_2017.reset_index(inplace=True)

# %%
df_2017.head(25)
# Out:
#      Tm  Unnamed: 0    Year                 Player Pos   Age      MP     FT  \
# 0   OKC       24654  2017.0      Russell Westbrook  PG  28.0  2802.0  710.0
# 1   HOU       24306  2017.0           James Harden  PG  27.0  2947.0  746.0
# 2   BOS       24612  2017.0          Isaiah Thomas  PG  27.0  2569.0  590.0
# 3   NOP       24218  2017.0          Anthony Davis   C  23.0  2708.0  519.0
# 4   MIN       24625  2017.0     Karl-Anthony Towns   C  21.0  3030.0  356.0
# 5   POR       24421  2017.0         Damian Lillard  PG  26.0  2694.0  488.0
# 6   TOR       24226  2017.0          DeMar DeRozan  SG  27.0  2620.0  545.0
# 7   GSW       24216  2017.0          Stephen Curry  PG  28.0  2638.0  325.0
# 8   CLE       24365  2017.0           LeBron James  SF  32.0  2794.0  358.0
# 9   TOT       24206  2017.0       DeMarcus Cousins   C  26.0  2465.0  517.0
# 10  MIN       24658  2017.0         Andrew Wiggins  SF  21.0  3048.0  412.0
# ...
